# %%
cd drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/KERC21Dataset/KERC21Dataset/preprocessed
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/KERC21Dataset/KERC21Dataset/preprocessed

# %%
import pandas as pd
import shutil

# %%
test_set_label = pd.read_csv('./test_set_labels.csv')
test_set_label
# Out:
#           Id label
# 0   f3UikyfG  HAHV
# 1   hPXobNGp  LAHV
# 2   6wtwdvGE  LALV
# 3   kS2BNtN3  HALV
# 4   5yUCwvfa  LALV
# ..       ...   ...
# 85  EKzKV73X  LALV
# 86  4FSXusMU  HALV
# 87  ERLxCGmz  LALV
# 88  h4XDGi4i  LAHV
# 89  b7BAW8wT  LALV
#
# [90 rows x 2 columns]

# %%
file_names = list(test_set_label['Id'])

# %%
src = 'train/'
dir = 'test/'

# %%
for i in file_names:
    file_name = i + '_BVP.npy'
    shutil.move(src + file_name, dir + file_name)
    
    file_name = i + '_EDA.npy'
    shutil.move(src + file_name, dir + file_name)
    
    file_name = i + '_EEG_ftrs.npy'
    shutil.move(src + file_name, dir + file_name)

# %%
pwd
# Out:
# '/content/drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/KERC21Dataset/KERC21Dataset/preprocessed'

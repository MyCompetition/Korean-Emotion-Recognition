# %%
cd drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/
# Out:
# [Errno 2] No such file or directory: 'drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/'
# /content/drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/KERC21Dataset/KERC21Dataset

# %%
cd KERC21Dataset/KERC21Dataset/
# Out:
# [Errno 2] No such file or directory: 'KERC21Dataset/KERC21Dataset/'
# /content/drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/KERC21Dataset/KERC21Dataset

# %%
import pandas as pd

# %%
ls
# Out:
# first_submission.ipynb  train/                 val/
# preprocessed/           train_labels.csv       val_personality.csv
# submission.csv          train_personality.csv
# test_set.csv            train_set.csv

# %%
train_labels = pd.read_csv('./train_labels.csv')
train_personality = pd.read_csv('./train_personality.csv')

# %%
train_labels
# Out:
#            Id label
# 0    cpa8NaV6  HALV
# 1    BT4tWhnF  LALV
# 2    W4iG35hs  LAHV
# 3    NbQp2i6N  LALV
# 4    D7oTD3b2  HALV
# ..        ...   ...
# 685  EKzKV73X  LALV
# 686  4FSXusMU  HALV
# 687  ERLxCGmz  LALV
# 688  h4XDGi4i  LAHV
# 689  b7BAW8wT  LALV
#
# [690 rows x 2 columns]

# %%
train_personality
# Out:
#            Id  Extraversion  ...  Agreeableness  Openness
# 0    cpa8NaV6             2  ...              0         1
# 1    BT4tWhnF             2  ...              1         0
# 2    W4iG35hs             1  ...              2         0
# 3    NbQp2i6N             2  ...              1         0
# 4    D7oTD3b2             3  ...              3         0
# ..        ...           ...  ...            ...       ...
# 685  EKzKV73X             2  ...              1         0
# 686  4FSXusMU             0  ...              2         0
# 687  ERLxCGmz             2  ...              1         0
# 688  h4XDGi4i             0  ...              1         2
# 689  b7BAW8wT             2  ...              1         0
#
# [690 rows x 6 columns]

# %%
test_set = train_labels[600:]
train_set = train_labels[:600]

# %%
test_set_personality = train_personality[600:]
train_set_personality = train_personality[:600]

# %%
test_set.to_csv('./test_set.csv', index=False)
train_set.to_csv('./train_set.csv', index=False)

test_set_personality.to_csv('./test_set_personality.csv', index=False)
train_set_personality.to_csv('./train_set_personality.csv', index=False)

# %%
cd preprocessed/
# Out:
# /content/drive/Othercomputers/내 노트북/googleDrive/Korean-Emotion-Recognition/KERC21Dataset/KERC21Dataset/preprocessed

# %%
ls
# Out:
# test_personality.csv  train_labels.csv       val_personality.csv
# train/                train_personality.csv

# %%
import pandas as pd

val = pd.read_csv('val_personality.csv')
test = pd.read_csv('test_personality.csv')
val
# Out:
#            Id  Extraversion  ...  Agreeableness  Openness
# 0    dxCvM7kG             3  ...              2         2
# 1    a2uAufNU             1  ...              0         1
# 2    NqSmd4Yi             2  ...              2         0
# 3    VutzFqXz             3  ...              2         2
# 4    DHG84kJJ             2  ...              1         0
# ..        ...           ...  ...            ...       ...
# 229  VnKmjfNJ             0  ...              0         1
# 230  KUDubdYD             0  ...              3         0
# 231  BbsVhSQg             2  ...              2         0
# 232  i6gRxj9f             0  ...              2         0
# 233  C2qH8svE             1  ...              1         0
#
# [234 rows x 6 columns]

# %%
val = val.append(test)
val
# Out:
#            Id  Extraversion  ...  Agreeableness  Openness
# 0    dxCvM7kG             3  ...              2         2
# 1    a2uAufNU             1  ...              0         1
# 2    NqSmd4Yi             2  ...              2         0
# 3    VutzFqXz             3  ...              2         2
# 4    DHG84kJJ             2  ...              1         0
# ..        ...           ...  ...            ...       ...
# 283  TE5WPwMM             1  ...              0         1
# 284  gnSced5m             2  ...              2         0
# 285  TDZgd8Ax             0  ...              2         0
# 286  cNm7QDMP             1  ...              3         2
# 287  Uqz2Tbym             3  ...              2         0
#
# [522 rows x 6 columns]

# %%
val.to_csv('./val_personality.csv', index=False)

# %%
csv.to_csv('submission_KimboSoek.csv', index=False)

# %%
csv = pd.read_csv('submission_KimBoSoek.csv')
csv
# Out:
#             Id Predicted
# 0     2expHvQu      LAHV
# 1     2GxXMBY3      LALV
# 2     2pU4C4gF      LALV
# 3     2Rfinz4J      HAHV
# 4     2WbphZrp      HALV
# ...        ...       ...
# 1147  YbcmuVAg      HALV
# 1148  YYQUNhna      HAHV
# 1149  ZgvH8xYs      LALV
# 1150  ZLucymf5      HALV
# 1151  ZYSKWRfF      LAHV
#
# [1152 rows x 2 columns]

# %%
csv.to_csv('submission_KimBoSoek2.csv', index=False, quoting = 3)

# %%
csv = csv[:289]
csv
# Out:
#            Id Predicted
# 0    2expHvQu      LAHV
# 1    2GxXMBY3      LALV
# 2    2pU4C4gF      LALV
# 3    2Rfinz4J      HAHV
# 4    2WbphZrp      HALV
# ..        ...       ...
# 284  YYQUNhna      HAHV
# 285  ZgvH8xYs      LALV
# 286  ZLucymf5      HALV
# 287  ZYSKWRfF      LAHV
# 288  2expHvQu      LAHV
#
# [289 rows x 2 columns]
